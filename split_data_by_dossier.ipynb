# %%
from all import *
# Out:
# <style>.container { width:100% !important; }</style>

# %%
comm_data = getCommitteeSplitData()

# %%
# this only has Dossiers that we actually care about:
# only Dossiers of committees that we care about
for comm, data in comm_data.items():
    x = pd.unique(data["Dossier"])
    print(x)
# Out:
# ['2019/2028 (BUD)' '2019/2712 (RSP)' '2019/2803 (RSP)' '2019/2824 (RSP)'
#  '2019/2814 (RSP)' '2019/2804 (RSP)' '2019/2078 (DEC)' '2019/2070 (DEC)'
#  '2019/2073 (DEC)' '2019/2079 (DEC)' '2019/2055 (DEC)' '2019/2086 (DEC)'
#  '2019/2805 (RSP)' '2019/2211 (INI)' '2019/0101 (COD)' '2019/0070 (COD)'
#  '2019/2816 (RSP)' '2019/2213 (BUD)' '2019/0017 (COD)' '2018/0213 (COD)'
#  '2020/2531 (RSP)' '2018/0193 (COD)' '2019/2157 (INI)' '2019/2156 (INI)'
#  '2020/2070 (INI)' '2020/0006 (COD)' '2020/2042 (INI)' '2020/2021 (INI)'
#  '2020/0036 (COD)' '2020/2071 (INI)' '2020/2058 (INI)' '2020/2012 (INL)'
#  '2020/2076 (INI)' '2020/0097 (COD)' '2020/0000 (BUD)' '2020/2613(RSP)'
#  '2020/0102 (COD)' '2020/2006 (INL)' '2020/0106 (COD)' '2020/0108 (COD)'
#  '2020/0100 (COD)' '2020/0104 (COD)' '2019/2193 (INI)' '2020/2074 (INI)'
#  '2020/2532(RSP)' '2020/2137 (INI)' '2020/2134 (INI)' '2020/2077 (INI)'
#  '2020/2043 (INI)' '2020/2242 (INI)' '2020/2027 (INI)' '2020/2157 (DEC)'
# ...

# %%
dossiers = {}
for comm, data in getCommitteeSplitData().items():
    dossiers[comm] = pd.unique(data["Dossier"])
print(dossiers)
# Out:
# {'ENVI': array(['2019/2028 (BUD)', '2019/2712 (RSP)', '2019/2803 (RSP)',
#        '2019/2824 (RSP)', '2019/2814 (RSP)', '2019/2804 (RSP)',
#        '2019/2078 (DEC)', '2019/2070 (DEC)', '2019/2073 (DEC)',
#        '2019/2079 (DEC)', '2019/2055 (DEC)', '2019/2086 (DEC)',
#        '2019/2805 (RSP)', '2019/2211 (INI)', '2019/0101 (COD)',
#        '2019/0070 (COD)', '2019/2816 (RSP)', '2019/2213 (BUD)',
#        '2019/0017 (COD)', '2018/0213 (COD)', '2020/2531 (RSP)',
#        '2018/0193 (COD)', '2019/2157 (INI)', '2019/2156 (INI)',
#        '2020/2070 (INI)', '2020/0006 (COD)', '2020/2042 (INI)',
#        '2020/2021 (INI)', '2020/0036 (COD)', '2020/2071 (INI)',
#        '2020/2058 (INI)', '2020/2012 (INL)', '2020/2076 (INI)',
#        '2020/0097 (COD)', '2020/0000 (BUD)', '2020/2613(RSP)',
#        '2020/0102 (COD)', '2020/2006 (INL)', '2020/0106 (COD)',
#        '2020/0108 (COD)', '2020/0100 (COD)', '2020/0104 (COD)',
#        '2019/2193 (INI)', '2020/2074 (INI)', '2020/2532(RSP)',
# ...

# %%
## final result:

from all import *
x = getDossierData("ITRE")
print(x)
# Out:
# <style>.container { width:100% !important; }</style>
# ['2019/2028 (BUD)' '2019/2213 (BUD)' '2019/0151 (COD)' '2019/0152 (COD)'
#  '2019/2157 (INI)' '2019/2156 (INI)' '2020/2006 (INL)' '2019/2189 (INI)'
#  '2020/0006 (COD)' '2020/2070 (INI)' '2020/2071 (INI)' '2020/0036(COD)'
#  '2020/0036 (COD)' '2020/2076 (INI)' '2020/0106 (COD)' '2020/0108 (COD)'
#  '2020/0100 (COD)' '2020/0104 (COD)' '2020/2131 (INI)' '2020/1998 (BUD)'
#  '2020/2043 (INI)' '2020/2077 (INI)' '2019/2158 (INI)' '2020/2217 (INI)'
#  '2020/2241 (INI)' '2020/2242 (INI)' '2020/2216 (INI)' '2020/0141 (NLE)'
#  '2020/2265 (BUI)' '2020/0321 (COD)' '2020/0260 (NLE)' '2020/0360 (COD)'
#  '2020/0340 (COD)' '2021/2046 (INI)' '2020/0365 (COD)' '2021/2006 (INI)'
#  '2021/2013 (INI)' '2020/0359 (COD)' '2021/0048 (NLE)' '2021/0049 (COD)'
#  '2020/0353 (COD)' '2020/0361 (COD)' '2021/0045 (COD)' '2021/2011 (INI)'
#  '2021/2012 (INI)' '2021/0227 (BUD)' '2020/0374 (COD)' '2021/2077 (INI)'
# ...
