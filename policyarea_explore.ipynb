# %%
from all import *

# %%
PROCEDURE_POLICYAREA
# Out:
#      procedure_interinst_id  \
# 0            2013/0186(COD)
# 1            2013/0186(COD)
# 2            2012/0060(COD)
# 3            2012/0060(COD)
# 4            2012/0060(COD)
# ...                     ...
# 2456         2020/1996(BUD)
# 2457         2020/1996(BUD)
# 2458         2020/1999(BUD)
# 2459         2020/1999(BUD)
# 2460         2020/1998(BUD)
#
#                                        policy_area_name policy_area_id  \
# 0                         Air transport and air freight        3.20.01
# 1              Air transport agreements and cooperation     3.20.15.02
# 2                                    Public procurement        2.10.02
# 3                      Global economy and globalisation           5.03
# 4     Agreements and relations in the context of the...        6.20.01
# ...                                                 ...            ...
# 2456  Industrial restructuring, job losses, redundan...        4.15.05
# 2457                                        2020 budget        8.70.50
# 2458             Financing of the budget, own resources        8.70.01
# 2459                                        2020 budget        8.70.50
# 2460                                        2021 budget        8.70.51
#
#       policy_area_level
# 0                     3
# 1                     4
# 2                     3
# 3                     2
# 4                     3
# ...                 ...
# 2456                  3
# 2457                  3
# 2458                  3
# 2459                  3
# 2460                  3
#
# [2461 rows x 4 columns]

# %%
pa = PROCEDURE_POLICYAREA

# %%
pa["policy_area_level_one"] = pa["policy_area_id"].apply(lambda x: str(x).split(".")[0])

# %%
pa
# Out:
#      procedure_interinst_id  \
# 0            2013/0186(COD)
# 1            2013/0186(COD)
# 2            2012/0060(COD)
# 3            2012/0060(COD)
# 4            2012/0060(COD)
# ...                     ...
# 2456         2020/1996(BUD)
# 2457         2020/1996(BUD)
# 2458         2020/1999(BUD)
# 2459         2020/1999(BUD)
# 2460         2020/1998(BUD)
#
#                                        policy_area_name policy_area_id  \
# 0                         Air transport and air freight        3.20.01
# 1              Air transport agreements and cooperation     3.20.15.02
# 2                                    Public procurement        2.10.02
# 3                      Global economy and globalisation           5.03
# 4     Agreements and relations in the context of the...        6.20.01
# ...                                                 ...            ...
# 2456  Industrial restructuring, job losses, redundan...        4.15.05
# 2457                                        2020 budget        8.70.50
# 2458             Financing of the budget, own resources        8.70.01
# 2459                                        2020 budget        8.70.50
# 2460                                        2021 budget        8.70.51
#
#       policy_area_level policy_area_level_one
# 0                     3                     3
# 1                     4                     3
# 2                     3                     2
# 3                     2                     5
# 4                     3                     6
# ...                 ...                   ...
# 2456                  3                     4
# 2457                  3                     8
# 2458                  3                     8
# 2459                  3                     8
# 2460                  3                     8
#
# [2461 rows x 5 columns]

# %%
cosp = COSPONSORSHIP_EDGELIST

# %%
smallboy = pd.merge(cosp, pa, on="procedure_interinst_id")

# %%
bigboy = pd.merge(smallboy, DOCUMENT_ORGANIZATION, on = "document_eu_id")

# %%
bigboy.columns
# Out:
# Index(['amendment_id', 'person_id', 'person_full_name', 'document_eu_id',
#        'procedure_interinst_id', 'date', 'policy_area_name', 'policy_area_id',
#        'policy_area_level', 'policy_area_level_one', 'organization_abbr'],
#       dtype='object')

# %%
bigboy = getBigBoyDataFrame()

# %%
bigboy
# Out:
#          amendment_id  person_id  person_full_name document_eu_id  \
# 0                  18       1898     Ilana Cicurel      PE749.912
# 1                   3       1898     Ilana Cicurel      PE749.912
# 2                  16       1898     Ilana Cicurel      PE749.912
# 3                  21       1898     Ilana Cicurel      PE749.912
# 4                   5       1898     Ilana Cicurel      PE749.912
# ...               ...        ...               ...            ...
# 3027624        234496       2311   Charlie Weimers      PE736.383
# 3027625        234496       2343  Bert-Jan Ruissen      PE736.383
# 3027626        234496       2343  Bert-Jan Ruissen      PE736.383
# 3027627        389271       1059    Cornelia Ernst      PE755.979
# 3027628        389271       1059    Cornelia Ernst      PE755.979
#
#         procedure_interinst_id        date  \
# 0               2022/0906(COD)  2023-06-13
# 1               2022/0906(COD)  2023-06-13
# 2               2022/0906(COD)  2023-06-13
# 3               2022/0906(COD)  2023-06-13
# 4               2022/0906(COD)  2023-06-13
# ...                        ...         ...
# 3027624         2019/0164(NLE)  2022-09-08
# 3027625         2019/0164(NLE)  2022-09-08
# 3027626         2019/0164(NLE)  2022-09-08
# 3027627         2023/0102(NLE)  2023-10-30
# 3027628         2023/0102(NLE)  2023-10-30
#
#                                           policy_area_name policy_area_id  \
# 0                Court of Justice, Court of First Instance        8.40.04
# 1                Court of Justice, Court of First Instance        8.40.04
# 2                Court of Justice, Court of First Instance        8.40.04
# 3                Court of Justice, Court of First Instance        8.40.04
# 4                Court of Justice, Court of First Instance        8.40.04
# ...                                                    ...            ...
# 3027624    Relations with the countries of the Middle East     6.40.05.06
# 3027625  Bilateral economic and trade agreements and re...        6.20.03
# 3027626    Relations with the countries of the Middle East     6.40.05.06
# 3027627      External borders crossing and controls, visas        7.10.04
# 3027628  Asylum, refugees, displaced persons; Asylum, M...        7.10.06
#
#          policy_area_level organization_abbr
# 0                        3              JURI
# 1                        3              JURI
# 2                        3              JURI
# 3                        3              JURI
# 4                        3              JURI
# ...                    ...               ...
# 3027624                  4              AFET
# 3027625                  3              AFET
# 3027626                  4              AFET
# 3027627                  3              LIBE
# 3027628                  3              LIBE
#
# [3027629 rows x 10 columns]
