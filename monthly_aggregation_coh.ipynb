# %%
from all import *

# %%
coh_df = getCohDf()

# %%
coh_df
# Out:
#                 ITRE      ENVI      AFET
# 2019-07-24  0.029111  0.036545  0.031609
# 2019-10-07       NaN  0.016058       NaN
# 2019-10-10       NaN       NaN  0.083060
# 2019-10-10       NaN       NaN  0.049860
# 2019-10-14       NaN       NaN  0.218182
# ...              ...       ...       ...
# 2023-10-24       NaN  0.285714       NaN
# 2023-10-24       NaN  0.016129       NaN
# 2023-10-25       NaN  0.083333       NaN
# 2023-10-26       NaN       NaN  0.007782
# 2023-10-26       NaN       NaN  0.009399
#
# [347 rows x 3 columns]

# %%
coh_df.index = pd.to_datetime(coh_df.index)
monthly = coh_df.groupby(pd.Grouper(freq = "M"))

# %%
aggr = monthly.agg("mean")

# %%
aggr
# Out:
#                 ITRE      ENVI      AFET
# 2019-07-31  0.029111  0.036545  0.031609
# 2019-08-31       NaN       NaN       NaN
# 2019-09-30       NaN       NaN       NaN
# 2019-10-31       NaN  0.021950  0.115509
# 2019-11-30       NaN  0.094518  0.024873
# 2019-12-31       NaN  0.107968  0.108466
# 2020-01-31  0.008025  0.022523  0.020315
# 2020-02-29  0.021552  0.020402  0.014725
# 2020-03-31  0.020467  0.010427       NaN
# 2020-04-30       NaN  0.018172  0.030782
# 2020-05-31  0.012218  0.014177  0.017961
# 2020-06-30       NaN  0.025241  0.022365
# 2020-07-31  0.021619  0.029130  0.014728
# 2020-08-31  0.064716       NaN  0.040570
# 2020-09-30  0.021206  0.019134  0.014236
# 2020-10-31  0.032132  0.013204  0.009267
# 2020-11-30  0.019182  0.014173  0.019598
# 2020-12-31  0.033277  0.160279  0.025022
# 2021-01-31       NaN  0.008949  0.025633
# 2021-02-28  0.038560  0.013798  0.014232
# 2021-03-31  0.009430  0.006978  0.031953
# 2021-04-30  0.019388  0.094253  0.011437
# 2021-05-31  0.016271  0.027418  0.018436
# 2021-06-30  0.016769  0.009670  0.016630
# 2021-07-31  0.077877       NaN  0.029509
# 2021-08-31       NaN       NaN       NaN
# 2021-09-30  0.028172       NaN  0.016055
# 2021-10-31       NaN       NaN  0.008559
# 2021-11-30  0.007483  0.017215  0.031488
# 2021-12-31  0.020548  0.044247  0.021344
# 2022-01-31  0.034575  0.015208  0.011139
# 2022-02-28  0.011221  0.010109  0.019286
# 2022-03-31       NaN  0.004012  0.025034
# 2022-04-30  0.012237  0.008404  0.015182
# 2022-05-31  0.009349       NaN  0.016352
# 2022-06-30  0.007298  0.010408  0.012405
# 2022-07-31  0.051034  0.020135  0.018410
# 2022-08-31       NaN       NaN  0.020442
# 2022-09-30  0.019424  0.010730  0.062847
# 2022-10-31  0.014463  0.007564  0.006517
# 2022-11-30  0.020664  0.025782  0.019124
# 2022-12-31  0.024914  0.007999  0.026874
# 2023-01-31  0.029400  0.076928  0.037445
# 2023-02-28  0.038651  0.005600  0.011680
# 2023-03-31  0.013109  0.010011  0.023828
# 2023-04-30  0.005193  0.058974  0.013038
# 2023-05-31  0.012144  0.006485  0.015389
# 2023-06-30  0.006718  0.027268  0.013478
# 2023-07-31  0.028345  0.028816  0.022561
# 2023-08-31       NaN  0.010422  0.017289
# 2023-09-30  0.027968  0.026769  0.013468
# 2023-10-31  0.045284  0.064238  0.015503

# %%
for i in aggr.columns:
    aggr[i] = aggr[i].ffill()
aggr.plot(figsize=(20,20), linestyle='-', marker='.')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Most ugyanez csak quarterly aggregationnel.
