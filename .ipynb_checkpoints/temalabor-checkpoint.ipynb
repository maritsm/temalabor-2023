# %%
#TODO: decide whether to use pandas or networkx
# we're using networkx for now

import networkx as nx
import matplotlib.pyplot as plt
import csv

# %%
def createNxGraph(filename):
    G = nx.Graph()
    with open(filename, 'r') as inputfile:
        csvr = csv.reader(inputfile, delimiter=',')
        for line in csvr:
            # we add an edge between the ID of the proposition
            # and the ID of the MEPf
            G.add_node(line[0], bipartite = 0)
            G.add_node((line[6], line[7],line[8],line[9],line[10]), bipartite = 1)
            G.add_edge(line[0], (line[6], line[7],line[8],line[9],line[10]))
    return G

def listMEPs(filename):
    L = []
    with open(filename, 'r') as inputfile:
        csvr = csv.reader(inputfile, delimiter=',')
        for line in csvr:
            L.append((line[6], line[7],line[8],line[9],line[10]))
    return L

# %%
myGraph = createNxGraph("db/ep_cosponsorship_dataset.csv")
list_meps = listMEPs("db/ep_cosponsorship_dataset.csv")

# %%
print(f"Some information about this graph:\n"
        f"Number of nodes: {nx.number_of_nodes(myGraph)}\n"
        f"Number of edges: {nx.number_of_edges(myGraph)}\n")

print(f"The nodes in this graph include: {myGraph.nodes}")
# Out:
# Some information about this graph:
# Number of nodes: 259406
# Number of edges: 750579
#
# The nodes in this graph include: ['\ufeffAmendmentID', ('OfficialMEPID', 'MEPName', 'MemberState', 'EPGroup', 'NationalParty'), '892323', ('124704', 'Stanislav POLČÁK', 'Czechia', 'EPP', 'Mayors and Independents'), '880086', ('197572', 'Anna ZALEWSKA', 'Poland', 'ECR', 'Law and Justice'), '885326', ('94649', 'Catherine GRISET', 'France', 'ID', 'National Rally'), '891589', ('96725', 'Bas EICKHOUT', 'Netherlands', 'Greens/EFA', 'GreenLeft'), '881777', ('197770', 'Martin HOJSÍK', 'Slovakia', 'RE', 'Progressive Slovakia'), '888406', ('113892', 'Eric ANDRIEU', 'France', 'S&D', 'Socialist Party'), '890457', ('96711', 'Pascal CANFIN', 'France', 'RE', 'The Republic Forward'), '894926', '893171', '892450', '894881', '893914', '893108', ('37324', 'Adina-Ioana VĂLEAN', 'Romania', 'EPP', 'National Liberal Party'), '894291', '883936', ('197721', 'César LUENA', 'Spain', 'S&D', "Spanish Socialist Workers' Party"), ('197719', 'Cristina MAESTRE MARTÍN DE ALMAGRO', 'Spain', 'S&D', "Spanish Socialist Workers' Party"), ('125042', 'Javi LÓPEZ', 'Spain', 'S&D', "Socialists' Party of Catalonia"), ('197718', 'Nicolás GONZÁLEZ CASARES', 'Spain', 'S&D', "Spanish Socialist Workers' Party"), '889291', '885412', '884461', '879904', '890644', '879857', ('197935', 'Ivan Vilibor SINČIĆ', 'Croatia', 'NI', 'Human Shield'), '885362', '891635', ('197530', 'Joanna KOPCIŃSKA', 'Poland', 'ECR', 'Law and Justice'), '880857', ('125064', 'Maria SPYRAKI', 'Greece', 'EPP', 'New Democracy'), '888150', ('197593', 'Véronique TRILLET-LENOIR', 'France', 'RE', 'The Republic Forward'), '886342', '887149', '888086', ('96867', 'Maria da Graça CARVALHO', 'Portugal', 'EPP', 'Social Democratic Party'), '893879', ('96810', 'Carlo FIDANZA', 'Italy', 'ECR', 'Brothers of Italy'), '893221', ('124785', 'Maria GRAPINI', 'Romania', 'S&D', 'Social Democratic Party'), '887654', ('188636', 'John HOWARTH', 'United Kingdom', 'S&D', 'Labour Party'), '894783', ('125706', 'Jiří POSPÍŠIL', 'Czechia', 'EPP', 'TOP 09'), '881778', '884421', '893372', ('197767', 'Eugen JURZYCA', 'Slovakia', 'ECR', 'Freedom and Solidarity'), ('23788', 'Adam BIELAN', 'Poland', 'ECR', 'Law and Justice'), ('197538', 'Beata MAZUREK', 'Poland', 'ECR', 'Law and Justice'), ('96713', 'Evžen TOŠENOVSKÝ', 'Czechia', 'ECR', 'Civic Democratic Party'), '893286', '884484', '880531', '886091', '885447', '888054', '881629', '886288', ('24922', 'Pascal ARIMONT', 'Belgium', 'EPP', 'Christian Social Party'), '882597', '884341', '891348', '879855', ('124708', 'Dita CHARANZOVÁ', 'Czechia', 'RE', 'ANO 2011'), ('197444', 'Svenja HAHN', 'Germany', 'RE', 'Free Democratic Party'), '884436', '893420', '879923', '888314', '893432', ('183916', 'Alexandra GEESE', 'Germany', 'Greens/EFA', 'The Greens'), '881668', '893827', ('128483', 'Markus BUCHHEIT', 'Germany', 'ID', 'Alternative for Germany'), '892452', '885460', '889480', ('197463', 'Olivier CHASTEL', 'Belgium', 'RE', 'Reformist Movement'), '880572', ('197788', 'Anna BONFRISCO', 'Italy', 'ID', 'League'), ('197799', 'Valentino GRANT', 'Italy', 'ID', 'League'), ('197597', 'Hélène LAPORTE', 'France', 'ID', 'National Rally'), ('124831', 'Isabella ADINOLFI', 'Italy', 'NI', 'Five Star Movement'), ('197806', 'Annalisa TARDINO', 'Italy', 'ID', 'League'), ('124780', 'Marco ZANNI', 'Italy', 'ID', 'League'), ('197482', 'Joachim KUHS', 'Germany', 'ID', 'Alternative for Germany'), '894188', '892355', '881707', '894626', '888398', ('197826', 'Matteo ADINOLFI', 'Italy', 'ID', 'League'), '893960', '891330', ('197547', 'Irène TOLLERET', 'France', 'RE', 'The Republic Forward'), ('197504', 'Jérémy DECERLE', 'France', 'RE', 'The Republic Forward'), ('191693', 'Elsi KATAINEN', 'Finland', 'RE', 'Centre Party'), '884629', ('197512', 'Benoît BITEAU', 'France', 'Greens/EFA', 'Europe Ecology'), '881372', '880386', ('124862', 'Ulrike MÜLLER', 'Germany', 'RE', 'Free Voters'), ('197848', 'Atidzhe ALIEVA-VELI', 'Bulgaria', 'RE', 'Movement for Rights and Freedoms'), '892610', '882709', '883399', ('125045', 'Clara AGUILERA', 'S ...

# %%
nx.is_bipartite(myGraph)
# Out:
# True

# %%
mep_social_network = nx.projected(myGraph, multigraph = True)
