# %%
from all import *

# %%
DOCUMENT_ORGANIZATION
# Out:
#      document_eu_id organization_abbr
# 0         PE680.868              TRAN
# 1         PE680.885              TRAN
# 2         PE680.905              TRAN
# 3         PE695.192              INTA
# 4         PE699.064              INTA
# ...             ...               ...
# 3419      PE745.351              TRAN
# 3420      PE662.009              AFET
# 3421      PE719.796              ECON
# 3422      PE729.817              BUDG
# 3423      PE745.281              CULT
#
# [3424 rows x 2 columns]

# %% [markdown]
# ``Ha ezt joinoljátok az edgelist-re a document_eu_id oszlopon, utána tudtok szakbizottságra szűrni." - Levi

# %%
COSPONSORSHIP_EDGELIST
# Out:
#          amendment_id  person_id   person_full_name document_eu_id  \
# 0                  18       1898      Ilana Cicurel      PE749.912
# 1                  37       2002  Isabel Carvalhais      PE657.419
# 2                  38       2002  Isabel Carvalhais      PE657.419
# 3                  47       1369      Pascal Canfin      PE736.476
# 4                  50       1369      Pascal Canfin      PE736.476
# ...               ...        ...                ...            ...
# 1172013        448512        216       Rovana Plumb      PE738.577
# 1172014        448512       2033     Andris Ameriks      PE738.577
# 1172015        448512       1955     Erik Bergkvist      PE738.577
# 1172016        448512       2383   Andreas Schieder      PE738.577
# 1172017        448512       1650      Maria Grapini      PE738.577
#
#         procedure_interinst_id        date
# 0               2022/0906(COD)  2023-06-13
# 1               2020/0095(COD)  2020-10-06
# 2               2020/0095(COD)  2020-10-06
# 3               2021/0423(COD)  2022-09-15
# 4               2021/0423(COD)  2022-09-15
# ...                        ...         ...
# 1172013         2021/0420(COD)  2023-01-25
# 1172014         2021/0420(COD)  2023-01-25
# 1172015         2021/0420(COD)  2023-01-25
# 1172016         2021/0420(COD)  2023-01-25
# 1172017         2021/0420(COD)  2023-01-25
#
# [1172018 rows x 6 columns]

# %%
cosp = COSPONSORSHIP_EDGELIST
docorg = DOCUMENT_ORGANIZATION

# %%
cosp['document_eu_id'] = cosp['document_eu_id'].astype(str)
docorg['document_eu_id'] = docorg['document_eu_id'].astype(str)

# %%
docorg.dtypes
# Out:
# document_eu_id       object
# organization_abbr    object
# dtype: object

# %%
# idk why this gives an error
# maybe some pointer-related shenanigans ??
bigboy = docorg.join(cosp, on="document_eu_id")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_402682/1487429986.py in <module>
#       1 # idk why this gives an error
# ----> 2 bigboy = docorg.join(cosp, on="document_eu_id")
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9261         5  K1  A5   B1
#    9262         """
# -> 9263         return self._join_compat(
#    9264             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9265         )
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9292                     sort=sort,
#    9293                 )
# -> 9294             return merge(
#    9295                 self,
#    9296                 other,
#
# ~/.local/lib/python3.10/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#
# ~/.local/lib/python3.10/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     702         # validate the merge keys dtypes. We may need to coerce
#     703         # to avoid incompatible dtypes
# --> 704         self._maybe_coerce_merge_keys()
#     705
#     706         # If argument passed to validate,
#
# ~/.local/lib/python3.10/site-packages/pandas/core/reshape/merge.py in _maybe_coerce_merge_keys(self)
#    1259                     inferred_right in string_types and inferred_left not in string_types
#    1260                 ):
# -> 1261                     raise ValueError(msg)
#    1262
#    1263             # datetimelikes must match exactly
#
# ValueError: You are trying to merge on object and int64 columns. If you wish to proceed you should use pd.concat
