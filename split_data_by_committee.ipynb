# %%
from all import *
# Out:
# <style>.container { width:100% !important; }</style>

# %%
important_committees = ["ENVI", "AFET", "ITRE"]

# %%
imp_comm_datasets = {}
for comm in important_committees:
    imp_comm_datasets[comm] = ENTIRE_DATASET.loc[ENTIRE_DATASET["Committee"] == comm]

# %%
# works!
imp_comm_datasets["ITRE"]
# Out:
#         AmendmentID Committee          Dossier        Date         PENumber  \
# 626          882780      ITRE  2019/2028 (BUD)  06/09/2019  PE641.091v01-00
# 627          887244      ITRE  2019/2028 (BUD)  06/09/2019  PE641.091v01-00
# 628          895983      ITRE  2019/2028 (BUD)  06/09/2019  PE641.091v01-00
# 629          880985      ITRE  2019/2028 (BUD)  06/09/2019  PE641.091v01-00
# 630          888430      ITRE  2019/2028 (BUD)  06/09/2019  PE641.091v01-00
# ...             ...       ...              ...         ...              ...
# 744188      1159135      ITRE  2021/0425 (COD)  15/07/2022  PE735.492v01-00
# 744189      1160409      ITRE  2021/0425 (COD)  15/07/2022  PE735.492v01-00
# 744190      1161036      ITRE  2021/0425 (COD)  15/07/2022  PE735.492v01-00
# 744191      1154697      ITRE  2021/0425 (COD)  15/07/2022  PE735.492v01-00
# 744192      1154697      ITRE  2021/0425 (COD)  15/07/2022  PE735.492v01-00
#
#         DocumentType OfficialMEPID               MEPName MemberState  \
# 626     DraftOpinion        125128       Iskra MIHAYLOVA    Bulgaria
# 627     DraftOpinion         96833            Jens GEIER     Germany
# 628     DraftOpinion        197399       Jessica STEGRUD      Sweden
# 629     DraftOpinion         96833            Jens GEIER     Germany
# 630     DraftOpinion         28340         Patrizia TOIA       Italy
# ...              ...           ...                   ...         ...
# 744188   DraftReport        124856        Ignazio CORRAO       Italy
# 744189   DraftReport        124856        Ignazio CORRAO       Italy
# 744190   DraftReport        124856        Ignazio CORRAO       Italy
# 744191   DraftReport         23816          András GYÜRK     Hungary
# 744192   DraftReport        213330  Ernő SCHALLER-BAROSS     Hungary
#
#            EPGroup                       NationalParty
# 626             RE    Movement for Rights and Freedoms
# 627            S&D  Social Democratic Party of Germany
# 628            ECR                    Sweden Democrats
# 629            S&D  Social Democratic Party of Germany
# 630            S&D                    Democratic Party
# ...            ...                                 ...
# 744188  Greens/EFA                         Independent
# 744189  Greens/EFA                         Independent
# 744190  Greens/EFA                         Independent
# 744191          NI   Fidesz - Hungarian Civic Alliance
# 744192          NI   Fidesz - Hungarian Civic Alliance
#
# [80223 rows x 11 columns]
